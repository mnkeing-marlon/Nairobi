# %% [markdown]
# **Sur les differents jeux**:
# - Les tailles de donnees mensuelles sont generalement entre 120000 et 170.000 enregistrements
# - Tous les jeux ont les memes 8 colonnes, certains avec une **Colonne1** en plus ( meme si elle est inutile)
# - La nuisance sonore **noise_Leq** n'est pas utilisable car n'est pas founie chaque mois
# - Les donnees ne sont pas recuperees chaque mois dans chaque **localitions** ce qui nous oblige a faire des predictions paralleles.

# %% [markdown]
# **Architecture**
#
# C:\Users\hp\Desktop\works\donnees\
# ├── pourcapteurs\
# │   ├── capteur_76_Nov2025.csv
# │   ├── capteur_3981_Nov2025.csv
# │   └── ...
# ├── pourmodele\
# │   ├── modele_76_Nov2025.csv
# │   ├── modele_3981_Nov2025.csv
# │   └── ...
# └── pourvisuel\
#     ├── visuel_76_Nov2025.csv
#     ├── visuel_3981_Nov2025.csv
#     └── ...
